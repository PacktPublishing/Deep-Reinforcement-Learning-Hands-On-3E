# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
import seaborn as sb
import pandas as pd

# %%
import os

# %%
def model_index(file_name):
    return int(file_name.split('_')[1])

# %%
def read_leaderboard(file_name, scale=False):
    result = []
    with open(file_name, "rt", encoding='utf-8') as fd:
        started = False
        for l in fd:
            l = l.strip()
            if not started:
                if l.startswith("Leaderboard"):
                    started = True
                continue
            name, rest = l.split(':')
            wld = map(str.strip, rest.split(','))
            win, lose, draw = map(lambda s: int(s.split('=')[1]), wld)
            # models from the last round played 40% more games, so score need to be compensated
            if scale:
                win = int(win / 1.4)
                lose = int(lose / 1.4)
                draw = int(draw / 1.4)
            result.append((os.path.basename(name), win, lose, draw))
    return result

# %% [markdown]
# # Semi-final analisys

# %%
v1 = read_leaderboard("semi-v1.txt")
v2 = read_leaderboard("semi-v2.txt");

# %%
v1[:10]
# Out:
# [('best_088_39300.dat', 1027, 732, 1),
#  ('best_025_09900.dat', 1024, 735, 1),
#  ('best_022_08200.dat', 1023, 737, 0),
#  ('best_021_08100.dat', 1017, 743, 0),
#  ('best_009_03400.dat', 1010, 749, 1),
#  ('best_014_04700.dat', 1003, 757, 0),
#  ('best_008_02700.dat', 998, 760, 2),
#  ('best_010_03500.dat', 997, 762, 1),
#  ('best_029_11800.dat', 991, 768, 1),
#  ('best_007_02300.dat', 980, 779, 1)]

# %%
v1_pairs = list(map(lambda p: (model_index(p[0]), p[1] / (p[1] + p[2] + p[3])), v1))
v1_pairs.sort()
v2_pairs = list(map(lambda p: (model_index(p[0]), p[1] / (p[1] + p[2] + p[3])), v2))
v2_pairs.sort()

# %%
v1_index, v1_ratios = zip(*v1_pairs)
v2_index, v2_ratios = zip(*v2_pairs)

# %%
plt.plot(v1_ratios)

# %%
plt.plot(v2_ratios)

# %%
v1_df = pd.DataFrame(data={
    "Wall time": [0] * len(v1_index), 
    'Step': v1_index, 
    'Value': v1_ratios
})
v2_df = pd.DataFrame(data={
    "Wall time": [0] * len(v2_index), 
    'Step': v2_index, 
    'Value': v2_ratios
})

# %%
v1_df.to_csv("v1-wins.csv", index=None)
v2_df.to_csv("v2-wins.csv", index=None)

# %%
def group_index(idx):
    if idx >= 100:
        return 9, idx - 90
    return idx // 10, idx % 10

# %%
groups = list(map(group_index, indices))

# %%
data = [[] for _ in range(10)]
for g, w in zip(groups, wins):
    data[g[0]].append(w)

# %%
for d in data:
    plt.plot(d[:10])
plt.xlabel("Index")
plt.ylabel("Score")
plt.savefig("semi-scores.png")

# %% [markdown]
# # Final scores

# %%
final_short = read_leaderboard("final.txt")
full_pairs = list(map(lambda p: (model_index(p[0]), p[1]), final_short))
full_pairs.sort(key=lambda p: p[0])
indices, wins = zip(*full_pairs)

# %%
plt.plot(indices, wins)
plt.xlabel("Model index")
plt.ylabel("Score gained")
plt.grid(True)
plt.savefig("final-short.png")

# %%
import pandas as pd

# %%
full_pairs = list(map(lambda p: (model_index(p[0]), p[1]/(p[1]+p[2]+p[3])), final_short))
full_pairs.sort(key=lambda p: p[0])
indices, ratios = zip(*full_pairs)

# %%
df = pd.DataFrame(data={'model_index': indices, 'wins': ratios})
df
# Out:
#     model_index      wins
# 0             6  0.532105
# 1             8  0.523684
# 2            10  0.426842
# 3            18  0.381316
# 4            20  0.467632
# 5            25  0.401316
# 6            37  0.471316
# 7            38  0.441053
# 8            46  0.475789
# 9            49  0.488684
# 10           50  0.508158
# 11           57  0.482105
# 12           66  0.556579
# 13           68  0.534474
# 14           72  0.561316
# 15           78  0.445526
# 16           87  0.567368
# 17           88  0.567105
# 18           91  0.593158
# 19          105  0.569211

# %%
df.to_csv("final.csv", index=None)

# %%
plt.plot(indices, ratios)
plt.xlabel("Model index")
plt.ylabel("Win ratio")
plt.grid(True)
plt.savefig("final-short.png")
